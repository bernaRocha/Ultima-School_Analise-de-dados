# %%
from bs4 import BeautifulSoup
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 from bs4 import BeautifulSoup
# ----> 2 import requests
#
# ModuleNotFoundError: No module named 'requests'

# %%
with open('Vagas_de_Analise_de_dados_LinkedIn.html', 'r', encoding='utf8') as f:
    fonte = f.read()

# %%
fonte
# Out:
# '<!DOCTYPE html>\n<!-- saved from url=(0109)https://www.linkedin.com/jobs/search/?currentJobId=3590214166&keywords=An%C3%A1lise%20de%20dados&refresh=true -->\n<html lang="pt" class="theme theme--mercado  artdeco-spacers artdeco windows"><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n    <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>\n\n    <title>Vagas de Análise de dados | LinkedIn</title>\n\n    \n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="asset-url" class="mercado-icons-sprite" id="artdeco-icons/static/images/sprite-asset" content="https://static.licdn.com/sc/h/dcxkx9v5dawqlrk4guhnx682m">\n    <meta name="description" content="">\n    <meta name="google" content="notranslate">\n    <meta name="serv
# ...

# %%
soup = BeautifulSoup(fonte, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!-- saved from url=(0109)https://www.linkedin.com/jobs/search/?currentJobId=3590214166&keywords=An%C3%A1lise%20de%20dados&refresh=true -->
# <html class="theme theme--mercado artdeco-spacers artdeco windows" lang="pt"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>Vagas de Análise de dados | LinkedIn</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static.licdn.com/sc/h/dcxkx9v5dawqlrk4guhnx682m" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# ...

# %%
tag_h2 = soup.find_all('h2')
print('Título da vaga')
print(tag_h2[3])

# %%
article = soup.find_all('article')
print(article)

# %% [markdown]
# ## Buscando por class ou id

# %%
id_nav = soup.find_all(attrs={'id': 'global-nav'})
id_nav
# Out:
# [<header class="global-nav global-alert-offset-top global-nav--hide-text global-nav--visible" id="global-nav">
#  <div class="global-nav__content">
#  <a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/?nis=true">
#  <div class="ivm-image-view-model global-nav__branding-logo">
#  <div class="ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag display-flex">
#  <li-icon aria-label="LinkedIn" class="" role="img" size="large" type="app-linkedin-bug-color-icon"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# ...
