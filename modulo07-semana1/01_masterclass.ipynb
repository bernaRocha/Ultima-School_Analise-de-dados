# %% [markdown]
# # Estatística

# %% [markdown]
# ### Diferenças entre média e mediana

# %%
import numpy as np

# %%
lista = np.random.randint(0, 10, 5)
lista
# Out:
# array([7, 7, 2, 3, 5])

# %%
print('A média é')
np.mean(lista)
# Out:
# A média é
# 4.8

# %%
print('A mediana é')
np.median(lista)
# Out:
# A mediana é
# 5.0

# %%
lista = np.append(lista, 100)
lista
# Out:
# array([  7,   7,   2,   3,   5, 100])

# %%
print('A média é')
np.mean(lista)
# Out:
# A média é
# 20.666666666666668

# %%
print('A mediana é')
np.median(lista)
# Out:
# A mediana é
# 6.0

# %% [markdown]
# ## Histogramas sobrepostos

# %%
import matplotlib.pyplot as plt

# %%
lista_rand = np.random.randint(0, 100, 100)

# %%
plt.hist(lista_rand);

# %%
plt.hist(lista_rand, bins=2);

# %%
plt.hist(lista_rand, bins=50);

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %% [markdown]
# #### kde (kernel density estimator), busca estimar uma f.d.p. (função densidade de probabilidade) da variável numérica

# %%
sns.kdeplot(lista_rand);

# %% [markdown]
# ## Covariância
# variância, é uma medida de dispersão que informa o quão distante cada valor desse conjunto está do valor central (médio). Caso desejemos medir a variação entre duas variáveis numéricas, podemos utilizar a covariância amostral

# %%
df[['total_bill', 'tip']].cov()
# Out:
#             total_bill       tip
# total_bill   79.252939  8.323502
# tip           8.323502  1.914455

# %% [markdown]
# O método .cov() do pandas informa a matriz de variância-covariância, indicando que a variância de total_bill e tip são 79,25 e 1,91, respectivamente, e a covariância entre elas é de 8,32.

# %%
sns.scatterplot(data=df, x="total_bill", y="tip");

# %% [markdown]
# ## Correlação
# A correlação normaliza a covariância para representar a relação entre 2 variáveis como um número que varia entre -1 e 1.

# %%
df[['total_bill', 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %% [markdown]
# ## Associações não lineares
# a relação entre duas variáveis pode ser monotônica, ou seja, as variáveis tendem a mudar juntas, mas não necessariamente a uma taxa constante <br>
# o <b>coeficiente de Spearman</b> não requer que a relação entre as variáveis seja linear. Inclusive, não requer que a variável seja contínua. Ou seja, podemos utilizá-lo para variáveis com medidas ordinais

# %%
df[['total_bill', 'tip', 'size']].corr(method='spearman')
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.678968  0.604791
# tip           0.678968  1.000000  0.468268
# size          0.604791  0.468268  1.000000

# %%
sns.boxplot(data=df, x="size", y="total_bill");

# %%
sns.scatterplot(data=df, x="total_bill", y="tip", hue="size");

# %% [markdown]
# ## Masterclass

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['total_bill'].hist();

# %%
sns.histplot(data=df, x='total_bill');

# %%
plt.hist(df['total_bill']);

# %%
sns.kdeplot(data=df, x='total_bill');

# %%
df['size'].hist();

# %%
sns.countplot(data=df, x='size');

# %%
total_bill_mean = df.total_bill.mean()
total_bill_median = df.total_bill.median()
total_bill_mode = df.total_bill.mode()

# %%
print(f"Média:   {total_bill_mean.round(3)} \nMediana: {total_bill_median} \nModa:    {total_bill_mode[0]}")
# Out:
# Média:   19.786
# Mediana: 17.795
# Moda:    13.42

# %%
plt.title("Função de densidade de probabilidade de total_bill")
plt.vlines(total_bill_mean, 0, 0.055, label="mean", colors="red")
plt.vlines(total_bill_median, 0, 0.055, label="median", colors="green")
plt.vlines(total_bill_mode, 0, 0.055, label="mode", colors="black")
sns.kdeplot(data=df, x ='total_bill')
plt.xlabel("Total da conta")
plt.ylabel("Densidade")
plt.legend();

# Há uma mistura de matplotlib e seaborn nesse gráfico

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.tip.hist();

# %%
plt.scatter(df.total_bill, df.tip);

# %%
df.plot(kind='scatter', x='total_bill', y='tip', title='total_bill X tip');

# %%
sns.scatterplot(data=df, x='total_bill', y='tip');

# %%
df[['total_bill', 'tip']].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
df[['total_bill', 'tip']].var()
# Out:
# total_bill    79.252939
# tip            1.914455
# dtype: float64

# %%
# total_bill com total_bill é a variância
df[['total_bill', 'tip']].cov()
# Out:
#             total_bill       tip
# total_bill   79.252939  8.323502
# tip           8.323502  1.914455

# %%
# por padrão é a correlação de Pearson
df[['total_bill', 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
sns.lmplot(data=df, x='total_bill', y='tip');

# %%
df[['total_bill', 'tip']].corr(method='spearman')
# Out:
#             total_bill       tip
# total_bill    1.000000  0.678968
# tip           0.678968  1.000000

# %% [markdown]
# ### Mais Matplotlib

# %%
df_flights = sns.load_dataset('flights')

# %%
df_flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.plot(df_flights['passengers']);

# %%
print('Histograma')
plt.hist(df_flights.year,bins=16);
# Out:
# Histograma

# %% [markdown]
# ### Vlines

# %%
tip_mean = df.tip.mean()

# %%
plt.vlines(tip_mean, 0, 60, colors='red')
plt.hist(df.tip, bins=20);

# %% [markdown]
# ### Título

# %%
plt.title('Distribuição de gorjeta')
plt.vlines(tip_mean, 0, 60, colors='red')
plt.hist(df.tip, bins=20);

# %% [markdown]
# ### Figsize

# %%
plt.figure(figsize=(10,4))
plt.title('Distribuição de gorjeta', size=10)
plt.vlines(tip_mean, 0, 60, colors='red')
plt.hist(df.tip, bins=20);

# %% [markdown]
# ### Subplots

# %%
_, ax = plt.subplots(1, 2, sharey=True)

ax[0].hist(df.total_bill)
ax[0].set_title('total_bill')

ax[1].hist(df.tip)
ax[1].set_title('tip')

plt.show()

# %% [markdown]
# ### Matplotlib no Pandas

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
(
    df.
    select_dtypes(include='float').
    hist()
);

# %% [markdown]
# ### Seaborn

# %%
sns.histplot(data=df, x='total_bill');

# %%
sns.histplot(data=df, x='total_bill', hue='sex');

# %%
sns.histplot(data=df, x='total_bill', hue='smoker');

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex');

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', hue='smoker');

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', hue='size');

# %% [markdown]
# ### Matplotlib + Seaborn

# %%
_, ax = plt.subplots(1, 2)

sns.histplot(data=df, x='total_bill', ax=ax[0]);
sns.histplot(data=df, x='tip', ax=ax[1]);

plt.tight_layout()
plt.show()

# %%
_, ax = plt.subplots(2, 2, figsize=(10, 6))

sns.histplot(data=df, x='total_bill', ax=ax[0, 0]);
sns.histplot(data=df, x='tip', ax=ax[0, 1]);

sns.countplot(data=df, x='sex', ax=ax[1, 0])
sns.countplot(data=df, x='smoker', ax=ax[1, 1])


plt.tight_layout()
plt.show()
